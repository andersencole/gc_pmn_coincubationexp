# %%
conda list
# Out:
# # packages in environment at /home/caandersen/.conda/envs/riptide_3.3.6:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# anyio                     4.10.0             pyhe01879c_0    conda-forge
# appdirs                   1.4.4              pyhd8ed1ab_1    conda-forge
# asttokens                 3.0.0              pyhd8ed1ab_1    conda-forge
# bzip2                     1.0.8                h4bc722e_7    conda-forge
# ca-certificates           2025.8.3             hbd8a1cb_0    conda-forge
# certifi                   2025.8.3           pyhd8ed1ab_0    conda-forge
# cobra                     0.29.1             pyhd8ed1ab_1    conda-forge
# comm                      0.2.3              pyhe01879c_0    conda-forge
# debugpy                   1.8.16          py313h5d5ffb9_0    conda-forge
# ...

# %%
pip list
# Out:
# Package                 Version
# ----------------------- -----------
# anyio                   4.10.0
# appdirs                 1.4.4
# asttokens               3.0.0
# certifi                 2025.8.3
# cobra                   0.29.1
# comm                    0.2.3
# debugpy                 1.8.16
# decorator               5.2.1
# depinfo                 2.2.0
# diskcache               5.6.3
# exceptiongroup          1.3.0
# executing               2.2.0
# future                  1.0.0
# h11                     0.16.0
# h2                      4.2.0
# hpack                   4.1.0
# httpcore                1.0.9
# httpx                   0.28.1
# hyperframe              6.1.0
# idna                    3.10
# importlib_metadata      8.7.0
# importlib_resources     6.5.2
# ipykernel               6.30.1
# ipython                 9.4.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.6.3
# jupyter_core            5.8.1
# ...

# %%
# These were added when setting up the kernel. I did not specify versions for the packages needed by riptide, as riptide specifically says a minimum package version is required. 
# The only specified version was that of riptide iteslf, 3.3.6, in this instance. 
# All non-riptide packages were added via conda, and riptide was PIP installed last.
